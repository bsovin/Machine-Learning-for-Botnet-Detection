# %%
# Завантаження бібліотек
import pandas as pd
from pandas import DataFrame

# %%
# Завантаження попередньо перетворених даних з .*pcap в *.csv формат
data = pd.read_csv("ISCX_Botnet-Training.csv")
df = DataFrame(data, columns=['Flow ID',
 'Src IP',
 'Src Port',
 'Dst IP',
 'Dst Port',
 'Protocol',
 'Timestamp',
 'Flow Duration',
 'Tot Fwd Pkts',
 'Tot Bwd Pkts',
 'TotLen Fwd Pkts',
 'TotLen Bwd Pkts',
# ... тут ще є назви колонок :p
 'Idle Max',
 'Idle Min',
 'Label',
 'isBot'])
print (df)

# %%
df['isBot']='benign'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '131.202.243.84')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '131.202.243.84')), 'isBot'] = 'bot' 
df.loc[((df['Src IP'] == '192.168.5.122') & (df['Dst IP'] == '198.164.30.2')|(df['Dst IP'] == '192.168.5.122') & (df['Src IP'] == '198.164.30.2')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.110') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.2.110') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.4.118') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.4.118') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.113') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.2.113') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.1.103') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.1.103') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.4.120') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.4.120') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.2.110')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.2.110')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.4.120')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.4.120')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.1.103')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.1.103')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.2.113')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.2.113')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.4.118')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.4.118')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.2.109')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.2.109')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.2.112') & (df['Dst IP'] == '192.168.2.105')|(df['Dst IP'] == '192.168.2.112') & (df['Src IP'] == '192.168.2.105')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.1.105') & (df['Dst IP'] == '192.168.5.122')|(df['Dst IP'] == '192.168.1.105') & (df['Src IP'] == '192.168.5.122')), 'isBot'] = 'bot'
     
# Опрацювання умови класифікації. Якщо IP адреса співпадає, то трафік пакет зловмисний
df.loc[((df['Src IP'] == '147.32.84.180') | (df['Dst IP'] == '147.32.84.180')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '147.32.84.170') | (df['Dst IP'] == '147.32.84.170')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '147.32.84.150') | (df['Dst IP'] == '147.32.84.150')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '147.32.84.140') | (df['Dst IP'] == '147.32.84.140')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '147.32.84.130') | (df['Dst IP'] == '147.32.84.130')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '147.32.84.160') | (df['Dst IP'] == '147.32.84.160')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '10.0.2.15') | (df['Dst IP'] == '10.0.2.15')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.106.141') | (df['Dst IP'] == '192.168.106.141')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.106.131') | (df['Dst IP'] == '192.168.106.131')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.16.253.130') | (df['Dst IP'] == '172.16.253.130')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.16.253.131') | (df['Dst IP'] == '172.16.253.131')), 'isBot'] = 'bot'

df.loc[((df['Src IP'] == '172.16.253.129') | (df['Dst IP'] == '172.16.253.129')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.16.253.240') | (df['Dst IP'] == '172.16.253.240')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '74.78.117.238') | (df['Dst IP'] == '74.78.117.238')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '158.65.110.24') | (df['Dst IP'] == '158.65.110.24')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.3.35') | (df['Dst IP'] == '192.168.3.35')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.3.25') | (df['Dst IP'] == '192.168.3.25')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.3.65') | (df['Dst IP'] == '192.168.3.65')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.29.0.116') | (df['Dst IP'] == '172.29.0.116')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.29.0.109') | (df['Dst IP'] == '172.29.0.109')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '172.16.253.132') | (df['Dst IP'] == '172.16.253.132')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '192.168.248.165') | (df['Dst IP'] == '192.168.248.165')), 'isBot'] = 'bot'
df.loc[((df['Src IP'] == '10.37.130.4 ') | (df['Dst IP'] == '10.37.130.4 ')), 'isBot'] = 'bot'
     
              
print (df.isBot.head(15))
df.to_csv (r'Class_isBot.csv', header=True, index=False)
# Out:
# 0     benign
# 1        bot
# 2        bot
# 3        bot
# 4        bot
# 5        bot
# 6        bot
# 7        bot
# 8        bot
# 9     benign
# 10       bot
# 11       bot
# 12       bot
# 13       bot
# 14       bot
# 15       bot
# 16       bot
# 17       bot
# 18       bot
# 19       bot
# Name: isBot, dtype: object

# %%
# Вивід класифікаційних даних в необхідну колонку
data = pd.read_csv("Class_isBot.csv")
print (data)
# Out:
#                                         Flow ID         Src IP  Src Port  \
# 0                         8.0.6.4-8.6.0.1-0-0-0        8.6.0.1         0
# 1        147.32.84.180-147.32.84.255-137-137-17  147.32.84.180       137
# 2          147.32.80.9-147.32.84.180-53-1025-17  147.32.84.180      1025
# 3         147.32.84.180-94.63.149.152-1040-80-6  147.32.84.180      1040
# 4         147.32.84.180-94.63.149.152-1040-80-6  147.32.84.180      1040
# ...                                         ...            ...       ...
# 356154      192.168.3.117-65.54.81.16-2476-80-6    65.54.81.16        80
# 356155    142.166.14.69-192.168.2.113-80-1387-6  142.166.14.69        80
# 356156   192.168.5.122-198.164.30.2-59564-53-17  192.168.5.122     59564
# 356157   192.168.5.122-198.164.30.2-43235-53-17  192.168.5.122     43235
# 356158  192.168.5.122-192.168.5.124-53-46544-17  192.168.5.124     46544
#
#                Dst IP  Dst Port  Protocol         Timestamp  Flow Duration  \
# ...
