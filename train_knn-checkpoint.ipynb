# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("isBot.csv")
df = DataFrame(data, columns=['Src IP',
'Src Port',
'Dst IP',
'Dst Port',
'Protocol',
'Flow Duration',
'Tot Fwd Pkts',
'Tot Bwd Pkts',
'isBot'])
df
# Out:
#                Src IP  Src Port         Dst IP  Dst Port  Protocol  \
# 0             8.6.0.1         0        8.0.6.4         0         0
# 1       147.32.84.180       137  147.32.84.255       137        17
# 2       147.32.84.180      1025    147.32.80.9        53        17
# 3       147.32.84.180      1040  94.63.149.152        80         6
# 4       147.32.84.180      1040  94.63.149.152        80         6
# ...               ...       ...            ...       ...       ...
# 356154    65.54.81.16        80  192.168.3.117      2476         6
# 356155  142.166.14.69        80  192.168.2.113      1387         6
# 356156  192.168.5.122     59564   198.164.30.2        53        17
# 356157  192.168.5.122     43235   198.164.30.2        53        17
# 356158  192.168.5.124     46544  192.168.5.122        53        17
#
#         Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  isBot
# 0          59086131.0             7             1      0
# ...

# %%
le = preprocessing.LabelEncoder()
srcip = le.fit_transform(list(data['Src IP']))
srcport = le.fit_transform(list(data['Src Port']))
dstip = le.fit_transform(list(data['Dst IP']))
dstport = le.fit_transform(list(data['Dst Port']))
protocol = le.fit_transform(list(data['Protocol']))
flowdur = le.fit_transform(list(data['Flow Duration']))
fwdpack = le.fit_transform(list(data['Protocol']))
bwdpack = le.fit_transform(list(data['Flow Duration']))

bot = le.fit_transform(list(data['isBot']))

predict = 'isBot'

X = list(zip(srcip, srcport, dstip, dstport, protocol, flowdur))
y = list(bot)
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
    
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9826482479784366

# %%
model = KNeighborsClassifier(n_neighbors=6)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.981300539083558

# %%
model = KNeighborsClassifier(n_neighbors=7)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.980205525606469

# %%
model = KNeighborsClassifier(n_neighbors=8)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9807670709793351

# %%
model = KNeighborsClassifier(n_neighbors=9)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9802897574123989

# %%
model = KNeighborsClassifier(n_neighbors=10)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9799528301886793

# %%
model = KNeighborsClassifier(n_neighbors=11)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9796720575022462

# %%
model = KNeighborsClassifier(n_neighbors=12)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9793912848158132

# %%
model = KNeighborsClassifier(n_neighbors=13)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9792228212039533

# %%
model = KNeighborsClassifier(n_neighbors=14)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9786331985624438

# %%
model = KNeighborsClassifier(n_neighbors=15)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9781278077268644

# %%
model = KNeighborsClassifier(n_neighbors=16)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9779874213836478

# %%
model = KNeighborsClassifier(n_neighbors=17)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9776504941599281

# %%
model = KNeighborsClassifier(n_neighbors=18)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9772854896675651

# %%
model = KNeighborsClassifier(n_neighbors=19)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9770047169811321

# %%
model = KNeighborsClassifier(n_neighbors=20)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.mean(y_pred == y_test))
# Out:
# 0.9769485624438454

# %%
acc = [0.9826482479784366, 0.981300539083558, 0.980205525606469, 0.9807670709793351, 0.9802897574123989, 0.9799528301886793, 0.9796720575022462, 0.9793912848158132, 0.9792228212039533, 0.9786331985624438, 0.9781278077268644, 0.9779874213836478, 0.9776504941599281, 0.9772854896675651, 0.9770047169811321, 0.9769485624438454]
plt.figure(figsize=(10, 10))
plt.plot(range (5,21), acc, color='gray', linestyle='dashed', marker='o',markerfacecolor='yellow', markersize=10)
plt.title('Accuracy Rate for K Value', fontsize=15)
plt.xlabel('K Value', fontsize=15)
plt.ylabel('Testing Accuracy', fontsize=15)
plt.tick_params(labelsize=15)

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

plt.figure(figsize=(10,10))
cm = confusion_matrix(y_test, y_pred)
print (cm)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Yes', 'Actual No'], 
                                 index=['Predict Yes', 'Predict No'])
sns.set(font_scale=1.4)
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='GnBu')
plt.tick_params(labelsize=15);

print(classification_report(y_test, y_pred))
# Out:
# [[24107   244]
#  [  374 10891]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     24351
#            1       0.98      0.97      0.97     11265
#
#     accuracy                           0.98     35616
#    macro avg       0.98      0.98      0.98     35616
# weighted avg       0.98      0.98      0.98     35616

# %%
predicted = model.predict(x_test)
names = ['bening', 'bot']

for x in range(len(predicted)):
    print("Predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
    n = model.kneighbors([x_test[x]], 5, True)
    print("N: ", n)
# Out:
# Predicted:  bot Data:  [ 0.1381432  -0.63931454 -0.76424268  0.30332284 -0.48938252  1.45333444] Actual:  bot
# N:  (array([[0.00427068, 0.01141857, 0.03079219, 0.0315378 , 0.03644081]]), array([[174461, 150861, 248365, 319713, 304703]], dtype=int64))
# Predicted:  bot Data:  [-0.42443909 -0.62261386 -0.85449227  0.5521395  -0.48938252  1.14269506] Actual:  bot
# N:  (array([[0.00221018, 0.00302479, 0.00320492, 0.00395527, 0.00582366]]), array([[243012, 287651, 277929,  15859, 151374]], dtype=int64))
# Predicted:  bot Data:  [-0.82971163 -0.60782965 -1.45773181 -0.35437241 -0.48938252 -0.97855647] Actual:  bot
# N:  (array([[0.00013511, 0.00024813, 0.00036123, 0.00046959, 0.00047434]]), array([[173556,  80981,   9687,  85187,  67706]], dtype=int64))
# Predicted:  bening Data:  [ 0.12747813 -0.55261702  1.26689025 -0.35437241 -0.48938252  0.87792476] Actual:  bening
# ...
